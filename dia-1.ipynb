# %%
platillo=input("Ingrese la comida que desea. ")
cantidad_platos=int(input("Ingrese la cantidad de platos que desea ordenar"))
costo = 15000
nro_orden = 0
def cocinar(comida,cantidad,precio,turno):
    total=precio*cantidad
    print("Su orden: nro",turno," de ",cantidad," platos de "+comida+" esta lista, abone ",total)
    turno+=1
    return turno
    

nro_orden=cocinar(platillo,cantidad_platos,costo,nro_orden)
# Out:
# Su orden: nro 0  de  2  platos de pizza esta lista, abone  30000

# %%
impuesto= 1.1

def calcular_total():
    monto_producto= int(input("ingrese precio del producto."))
    total= monto_producto*impuesto
    print("total: ",total)

calcular_total()
# Out:
# total:  11000.0
